# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
# read in csv.
dfold = pd.read_csv("ALLtheGALLJune2020.csv")
dfold.head()
# Out:
#    clip-index  trick-index             trick switch / nollie line slowmo  \
# 0           1            1            bs 180             NaN    1    NaN
# 1           1            2    fakie bs shove             NaN    1    NaN
# 2           1            3  fakie bs bigspin             NaN    1    NaN
# 3           1            4          fs shove             NaN    1    NaN
# 4           1            5        bs bigspin             NaN    1    NaN
#
#   obstacle obstacle-detailed location            video  year  \
# 0     flat               NaN      NaN  The Brotherhood  1991
# 1     flat               NaN      NaN  The Brotherhood  1991
# 2     flat               NaN      NaN  The Brotherhood  1991
# 3     flat               NaN      NaN  The Brotherhood  1991
# 4     flat               NaN      NaN  The Brotherhood  1991
#
#                            notes crust Unnamed: 13 Unnamed: 14
# 0                            NaN   NaN         NaN         NaN
# 1                            NaN   NaN         NaN         NaN
# 2  entire part filmed in one day   NaN         NaN         NaN
# 3                                  NaN         NaN
# 4                                  NaN         NaN         NaN

# %%
# read in csv.
df = pd.read_csv("allen.csv")
df.head()
# Out:
#    clip_index  trick_index                              trick  flannel  \
# 0           1            1                            fs shuv        1
# 1           1            2                        fs kickflip        1
# 2           2            3                              ollie        1
# 3           2            4  shuv it to pivot to shuv to fakie        1
# 4           3            5                 bs noseblunt slide        0
#
#    switch shorts w high socks   obstacle obstacle_detailer  slowmo  line  \
# 0       0                   0       flat               NaN       0     1
# 1       0                   0  into bank               NaN       0     1
# 2       0                   0       flat           up curb       0     1
# 3       0                   0      ledge        transition       0     1
# 4       0                   0      ledge         into bank       0     0
#
#    bank         video  year
# 0     0  Authentic Hi  2020
# 1     1  Authentic Hi  2020
# 2     0  Authentic Hi  2020
# 3     1  Authentic Hi  2020
# 4     1  Authentic Hi  2020

# %%
df.columns = ['clip_index', 'trick_index', 'trick', 'flannel', 'switch', 'shorts', 'obstacle',
             'obstacle_detailed', 'slowmo', 'line', 'bank', 'video', 'year']

# %%
df = df[['clip_index', 'trick_index', 'trick', 'flannel', 'switch', 'obstacle',
             'obstacle_detailed', 'slowmo', 'line', 'bank', 'video', 'year']]
df.head()
# Out:
#    clip_index  trick_index                              trick  flannel  \
# 0           1            1                            fs shuv        1
# 1           1            2                        fs kickflip        1
# 2           2            3                              ollie        1
# 3           2            4  shuv it to pivot to shuv to fakie        1
# 4           3            5                 bs noseblunt slide        0
#
#    switch   obstacle obstacle_detailed  slowmo  line  bank         video  year
# 0       0       flat               NaN       0     1     0  Authentic Hi  2020
# 1       0  into bank               NaN       0     1     1  Authentic Hi  2020
# 2       0       flat           up curb       0     1     0  Authentic Hi  2020
# 3       0      ledge        transition       0     1     1  Authentic Hi  2020
# 4       0      ledge         into bank       0     0     1  Authentic Hi  2020

# %%
# coerce columns to numeric
for col in ['switch', 'line', 'slowmo', 'bank', 'flannel']:
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

# %% [markdown]
# # Create percentage data for waffle plot

# %%
# total num_tricks 
num_tricks = pd.DataFrame(df.groupby('video')['trick_index'].max()).reset_index()
num_tricks.columns = ['video', 'num_tricks']

# total num clips
num_clips = pd.DataFrame(df.groupby('video')['clip_index'].max()).reset_index()
num_clips.columns = ['video', 'num_clips']

# total slowmo clips
num_slowmo = pd.DataFrame(df.groupby('video').sum()['slowmo']).reset_index()
num_slowmo.columns = ['video', 'num_slowmo']

# total flannel clips
num_flannel = pd.DataFrame(df.groupby('video').sum()['flannel']).reset_index()
num_flannel.columns = ['video', 'num_flannel']

# total switch/nollie tricks
num_switch = pd.DataFrame(df.groupby('video').sum()['switch']).reset_index()
num_switch.columns = ['video', 'num_switch']

# total distinct tricks
num_distinct = pd.DataFrame(df.groupby('video').nunique()['trick']).reset_index()
num_distinct.columns = ['video', 'num_distinct']

# total fs tricks
num_fs = pd.DataFrame(df[['trick', 'video', 'trick_index', 'obstacle']].drop_duplicates().groupby(['video'])['trick'].apply(lambda x: x[x.str.contains('fs ')].count())).reset_index()
num_fs.columns = ['video', 'num_fs_tricks']
    
# total bs tricks
num_bs = pd.DataFrame(df[['trick', 'video', 'trick_index', 'obstacle']].drop_duplicates().groupby(['video'])['trick'].apply(lambda x: x[x.str.contains('bs ')].count())).reset_index()
num_bs.columns = ['video', 'num_bs_tricks']

df_stats = df.merge(num_tricks).merge(num_clips).merge(num_slowmo).merge(num_switch).merge(num_distinct).merge(num_fs).merge(num_bs)


vids = df.groupby('video')

# percent stair
perc_stair = pd.DataFrame(vids['obstacle'].agg(lambda x: (len(x[x=='stair']) + len(x[x=='gap']) ) / len(x)))
perc_stair = perc_stair.reset_index()
perc_stair.columns = ['video', 'perc_stair']

# percent ledge
perc_ledge = pd.DataFrame(vids['obstacle'].agg(lambda x: (len(x[x=='ledge'])) / len(x)))
perc_ledge = perc_ledge.reset_index()
perc_ledge.columns = ['video', 'perc_ledge']

# percent manual
perc_manual = pd.DataFrame(vids['obstacle'].agg(lambda x: (len(x[x=='manual'])) / len(x)))
perc_manual = perc_manual.reset_index()
perc_manual.columns = ['video', 'perc_manual']

# percent transition
perc_transition = pd.DataFrame(vids['obstacle'].agg(lambda x: (len(x[x=='transition'])) / len(x)))
perc_transition = perc_transition.reset_index()
perc_transition.columns = ['video', 'perc_transition']

# percent flat
perc_flat = pd.DataFrame(vids['obstacle'].agg(lambda x: (len(x[x=='flat'])) / len(x)))
perc_flat = perc_flat.reset_index()
perc_flat.columns = ['video', 'perc_flat']

# percent handrail
perc_handrail = pd.DataFrame(vids['obstacle'].agg(lambda x: (len(x[x=='handrail'])) / len(x)))
perc_handrail = perc_handrail.reset_index()
perc_handrail.columns = ['video', 'perc_handrail']

# percent curb
perc_curb = pd.DataFrame(vids['obstacle_detailed'].agg(lambda x: (len(x[x=='curb'])) / len(x)))
perc_curb = perc_curb.reset_index()
perc_curb.columns = ['video', 'perc_curb']

# %%
new_df = df
for s in [num_tricks, num_clips, num_slowmo,  num_flannel, num_switch, num_distinct, num_fs, num_bs,
         perc_stair, perc_ledge, perc_manual, perc_transition, perc_flat, perc_handrail, perc_curb]:
    new_df = new_df.merge(s)

# %%
cols_to_keep = ['video', 'num_tricks', 'num_clips', 'num_slowmo', 'num_switch',
       'num_distinct', 'num_fs_tricks', 'num_bs_tricks',
       'perc_stair', 'perc_ledge', 'perc_manual', 'perc_transition',
       'num_flannel', 'perc_handrail', 'perc_curb', 'perc_flat']

# %%
stats_df = new_df[cols_to_keep].drop_duplicates().reset_index().drop(columns='index')

# %%
stats_df['perc_distinct'] = stats_df.apply(lambda x: x['num_distinct'] / x['num_tricks'], axis=1)

stats_df['perc_slowmo'] = stats_df.apply(lambda x: x['num_slowmo'] / x['num_tricks'], axis=1)

stats_df['perc_switch'] = stats_df.apply(lambda x: x['num_switch'] / x['num_tricks'], axis=1)

stats_df['perc_fs'] = stats_df.apply(lambda x: x['num_fs_tricks'] / x['num_tricks'], axis=1)

stats_df['perc_bs'] = stats_df.apply(lambda x: x['num_bs_tricks'] / x['num_tricks'], axis=1)

stats_df['perc_flannel'] = stats_df.apply(lambda x: x['num_flannel'] / x['num_tricks'], axis=1)

# %%
stats_df = stats_df.drop(columns=['num_tricks', 'num_clips', 'num_slowmo', 'num_switch', 'num_distinct', 
                       'num_fs_tricks', 'num_bs_tricks', 'num_flannel'])


stats_df['video'] = stats_df.video.str.replace(' - ', '_', regex=False).str.replace(' ', '_', regex=False).str.replace('é', 'e', regex=False).str.replace('-', '_', regex=False).str.replace('.', '', regex=False)

for col in ['perc_stair', 'perc_ledge', 'perc_manual', 'perc_transition',
       'perc_flannel', 'perc_handrail', 'perc_curb', 'perc_distinct',
       'perc_slowmo', 'perc_switch', 'perc_fs', 'perc_bs', 'perc_flat']:
    stats_df[col] = round(stats_df[col] * 100)

# %%
stats_df
# Out:
#                        video  perc_stair  perc_ledge  perc_manual  \
# 0               Authentic_Hi         0.0        47.0          0.0
# 1                   DOUBLE_A        15.0        30.0          0.0
# 2   Boys_of_Summer_Leftovers         2.0        29.0          0.0
# 3                 Hockey_III         6.0        21.0          0.0
# 4                 522_on_411        29.0        21.0          0.0
# 5             Boys_of_Summer         3.0        62.0          0.0
# 6       Welcome_to_Anti_Hero         9.0        14.0          0.0
# 7                  Hockey_II         8.0        28.0          0.0
# 8                  Propeller         7.0        14.0          0.0
# 9       Prevent_This_Tragedy        21.0        21.0          0.0
# 10       Propeller_Raw_Files         9.0        30.0          0.0
# 11           Spitfire_Wheels        18.0         9.0          0.0
# 12          411vm_Hot_Wheels        31.0        19.0          0.0
#
#     perc_transition  perc_handrail  perc_curb  perc_flat  perc_distinct  \
# 0               0.0            0.0        0.0       20.0           93.0
# 1               0.0            0.0        0.0        5.0           89.0
# 2               9.0            0.0        2.0       27.0           74.0
# 3              29.0            3.0        0.0       18.0           97.0
# 4               2.0           12.0        0.0       10.0           88.0
# 5               3.0            0.0       12.0       21.0           91.0
# 6              25.0            4.0        0.0       12.0           77.0
# 7              25.0            2.0        2.0       18.0           95.0
# 8              32.0            7.0        0.0        7.0          100.0
# 9               3.0           10.0        0.0       10.0           89.0
# 10             15.0            4.0        0.0       13.0           93.0
# 11             41.0            0.0        0.0       23.0           90.0
# 12             12.0           25.0        0.0        0.0          100.0
#
#     perc_slowmo  perc_switch  perc_fs  perc_bs  perc_flannel
# 0           7.0         20.0     13.0     60.0          40.0
# 1           0.0         28.0      6.0     28.0          17.0
# 2           0.0         13.0     26.0     28.0          22.0
# 3           3.0         24.0     21.0     38.0           3.0
# 4          12.0         36.0     30.0     26.0          38.0
# 5           0.0         38.0     38.0     50.0           6.0
# 6           0.0         21.0     26.0     28.0          19.0
# 7           3.0         38.0     31.0     33.0          23.0
# 8           0.0         63.0     26.0     52.0          30.0
# 9           3.0         49.0     27.0     51.0          35.0
# 10          0.0         37.0     37.0     30.0          22.0
# 11          5.0         10.0     24.0     43.0          43.0
# 12         12.0         25.0     50.0     50.0           0.0

# %%
stats_df.to_csv('gall_percs.csv')

# %%
stats_df.to_csv('../../../koston_article/data/gall_percs.csv', index=False)

# %% [markdown]
# # Number of Clips By Video

# %%
# total num tricks
aggregated = df.groupby('video').max()['clip_index']
aggregated.name = 'total_num_tricks'
aggregated.sort_values(ascending=False)
# Out:
# video
# Inhabitants                     63
# Decade of Destruction           50
# Brutality                       45
# The Other Ones                  36
# Frontside Skate Shop            33
# Worst Skater of the Year        30
# Mosaic                          29
# Real Life                       26
# Stacked                         25
# Photosynthesis                  24
# Timecode                        23
# Dirts Win                       16
# OJ Wheels                       16
# Eastern Exposure 2              15
# Real Street                     15
# The Brotherhood                 15
# Domestics                       13
# Last of the Mohicans            13
# Disturbed                       11
# Sober?                          10
# 411 #8                           9
# 411 # 30 AWS Ind.                8
# Thrasher Feats                   8
# Welcome to Seasons               7
# Eastern Exposure 3               4
# Habitat - Origins                3
# Habitat - Search the Horizon     3
# Zoo York - Peep This             3
# Name: total_num_tricks, dtype: int64

# %% [markdown]
# # Top Tricks

# %%
top_tricks = pd.DataFrame(df.trick.value_counts()).reset_index()
top_tricks.columns = ['trick', 'trickcount']
top_tricks = top_tricks[top_tricks.trickcount > 3]
top_tricks.to_csv('toptricks.csv', index=False)

# %%
top_tricks
# Out:
#                       trick  trickcount
# 0                     ollie          45
# 1                  360 flip          17
# 2                  fs ollie          14
# 3              switch ollie          14
# 4                  fs 50-50          14
# 5               bs wallride          13
# 6               fs wallride          10
# 7              bs 360 ollie          10
# 8             bs bluntslide           9
# 9             switch fs 180           9
# 10                 heelflip           8
# 11             fs tailslide           8
# 12               impossible           7
# 13              fs kickflip           7
# 14            fs boardslide           6
# 15              bs kickflip           5
# 16        bs pivot to fakie           5
# 17      bs crooked to fakie           5
# 18  switch fs 180 to fs 5-0           5
# 19                 bs shove           4
# 20                   nollie           4
# 21            switch bs 5-0           4
# 22        switch bs crooked           4
# 23                   fs 180           4
# 24                 fs shove           4
# 25     bs nosepick yank out           4
# 26   bs bluntslide to fakie           4

# %% [markdown]
# # Number of Clips Filmed By Year

# %%
clips_per_year = df.groupby('year').count()['clip_index']

# %%
sns.lineplot(data=clips_per_year)

# %% [markdown]
# # Crust over Time

# %%
crust_by_year = df.groupby('year').sum()['crust']

# %%
crust_df = pd.DataFrame(crust_by_year).reset_index()
crust_df.columns = ['year', 'num_crust_clips']
crust_df.to_csv('crust_df.csv', index=False)

# %% [markdown]
# # Obstacles Over Time
#
# To plot each obstacle over time, we first need to get the counts for obstacle by year.
#
# Then, we'll have to reformat our data to a 'long' structure suitable for plotting.

# %%
# group by to get counts
obs_by_time = df.groupby(['obstacle', 'year']).count()

# %%
# format data better
obs_by_time = obs_by_time.reset_index()[['obstacle', 'year', 'clip_index']].rename(columns={'clip_index': 'cnt'})
obs_by_time.to_csv('obs_by_time.csv', index=False)

# %%
# pivot data into desired structure
obs_by_time = obs_by_time.pivot(index="year", columns="obstacle", values="cnt").fillna(0)

# %%
# unfortunately, default plotting kind sucks but at least we get a general idea of trends
obs_by_time.plot(figsize=(20,10), lw=4)

# %%
# Rerun previous code but filter out some of the obstacles
desired_obstacles = ['rail', 'wall', 'stairs', 'transition', 'ledge']

obs_by_time = df.loc[df.obstacle.isin(desired_obstacles)].groupby(['obstacle', 'year']).count()
# format data better
obs_by_time = obs_by_time.reset_index()[['obstacle', 'year', 'clip_index']].rename(columns={'clip_index': 'cnt'})
# pivot data into desired structure
obs_by_time = obs_by_time.pivot(index="year", columns="obstacle", values="cnt").fillna(0)
# unfortunately, default plotting kind sucks but at least we get a general idea of trends
obs_by_time.plot(figsize=(20,10), lw=5)

# %%
sns.catplot("obstacle", col="year", 
                col_wrap=3, data=df, 
                kind="count", height=2.5, aspect=.8)

# %%
df
# Out:
#      clip_index  trick_index                                    trick  switch  \
# 0             1            1                                   bs 180     0.0
# 1             1            2                           fakie bs shove     0.0
# 2             1            3                         fakie bs bigspin     0.0
# 3             1            4                                 fs shove     0.0
# 4             1            5                               bs bigspin     0.0
# 5             1            6                                 bs shove     0.0
# 6             1            7                               impossible     0.0
# 7             2            8                                nose bonk     0.0
# 8             3            9                             bs noseslide     0.0
# 9             4           10                                   bs 180     0.0
# 10            5           11                              nose manual     0.0
# 11            6           12                             fs tailslide     0.0
# 12            7           13                               impossible     0.0
# 13            8           14             switch boardslide to regular     1.0
# 14            9           15                               bs bigspin     0.0
# 15           10           16                               impossible     0.0
# 16           11           17                                 360 flip     0.0
# 17           12           18                             bs 360 ollie     0.0
# 18           13           19                               impossible     0.0
# 19           14           20                                   nollie     1.0
# 20           15           21                               impossible     0.0
# 21            1            1                bs noseblunt to bs revert     0.0
# 22            2            2                fs noseblunt to bs revert     0.0
# 23            3            3              fs noseblunt to bs nosepick     0.0
# 24            4            4        fs noseblunt to tailgrab bs shove     0.0
# 25            5            5    bs shove to fs noseblunt to fs revert     0.0
# 26            6            6                       fs varial heelflip     0.0
# 27            7            7                                   fs 180     0.0
# 28            8            8                      ollie late fs shove     0.0
# 29            9            9             switch front foot impossible     1.0
# ..          ...          ...                                      ...     ...
# 624           4            5                                    ollie     0.0
# 625           5            6                              rock n roll     0.0
# 626           6            7  bs 180 to switch 5-0 stall to bs revert     0.0
# 627           7            8    bs kickflip to noseblunt to bs revert     0.0
# 628           8            9                 noseblunt stall yank out     0.0
# 629           9           10                                 fs 50-50     0.0
# 630          10           11             nosegrab fast plant to fakie     0.0
# 631          11           12                                no comply     0.0
# 632          11           13                                    ollie     0.0
# 633          11           14                               fs roll in     0.0
# 634          12           15                                    ollie     0.0
# 635          13           16                           fakie kickflip     0.0
# 636           1            1                            bs bluntslide     0.0
# 637           2            2                      bean plant to fakie     0.0
# 638           3            3                           fakie kicklfip     0.0
# 639           4            4             switch bs crooked to forward     0.0
# 640           5            5                                 bs carve     0.0
# 641           5            6                    bs carve to fs revert     0.0
# 642           6            7                              bs wallride     0.0
# 643           7            8               fs shove to blunt to fakie     0.0
# 644           8            9  bs 180 to switch 5-0 stall to bs revert     0.0
# 645           9           10          switch bs boardslide to forward     1.0
# 646          10           11                   bs bluntslide to fakie     0.0
# 647          11           12                              bs wallride     0.0
# 648          12           12                              bs wallride     0.0
# 649          13           13                              fs kickflip     0.0
# 650          14           14                 fs ollie to fs tailslide     0.0
# 651          14           15                              hippie jump     0.0
# 652          15           16                 noseblunt stall yank out     0.0
# 653          16           17                  kickflip to bs wallride     0.0
#
#      line  slowmo    obstacle   obstacle_detailed   location            video  \
# 0     1.0     0.0        flat                 NaN        NaN  The Brotherhood
# 1     1.0     0.0        flat                 NaN        NaN  The Brotherhood
# 2     1.0     0.0        flat                 NaN        NaN  The Brotherhood
# 3     1.0     0.0        flat                 NaN        NaN  The Brotherhood
# 4     1.0     0.0        flat                 NaN        NaN  The Brotherhood
# 5     1.0     0.0        flat                 NaN        NaN  The Brotherhood
# 6     1.0     0.0        flat                 NaN        NaN  The Brotherhood
# 7     0.0     0.0        flat             to drop        NaN  The Brotherhood
# 8     0.0     0.0        rail                 NaN        NaN  The Brotherhood
# 9     0.0     0.0      stairs                 NaN        NaN  The Brotherhood
# 10    0.0     0.0  manual pad             to drop        NaN  The Brotherhood
# 11    0.0     0.0       ledge           out ledge        NaN  The Brotherhood
# 12    0.0     0.0        flat             to drop        NaN  The Brotherhood
# 13    0.0     0.0       ledge           out ledge        NaN  The Brotherhood
# 14    0.0     0.0      stairs                 NaN        NaN  The Brotherhood
# 15    0.0     0.0      stairs                 NaN        NaN  The Brotherhood
# 16    0.0     0.0      stairs                 NaN        NaN  The Brotherhood
# 17    0.0     0.0      stairs                 NaN        NaN  The Brotherhood
# 18    0.0     0.0      stairs                 NaN        NaN  The Brotherhood
# 19    1.0     0.0      stairs                 NaN        NaN  The Brotherhood
# 20    1.0     0.0        flat                 NaN        NaN  The Brotherhood
# 21    0.0     0.0  transition             quarter        NaN          Stacked
# 22    0.0     0.0  transition             quarter        NaN          Stacked
# 23    0.0     0.0  transition             quarter        NaN          Stacked
# 24    0.0     0.0  transition             quarter        NaN          Stacked
# 25    0.0     0.0  transition             quarter        NaN          Stacked
# 26    0.0     0.0        flat                 NaN        NaN          Stacked
# 27    0.0     0.0      stairs                 NaN        NaN          Stacked
# 28    0.0     1.0      stairs                 NaN        NaN          Stacked
# 29    0.0     0.0      stairs                 NaN        NaN          Stacked
# ..    ...     ...         ...                 ...        ...              ...
# 624   0.0     0.0        flat           over rail        NaN        Domestics
# 625   0.0     0.0  transition                pool        NaN        Domestics
# 626   0.0     0.0  transition      street quarter      ditch        Domestics
# 627   0.0     0.0  transition      street quarter      ditch        Domestics
# 628   0.0     0.0  transition      street quarter        NaN        Domestics
# 629   0.0     0.0        rail            handrail        NaN        Domestics
# 630   0.0     0.0  transition      street quarter        NaN        Domestics
# 631   1.0     0.0        curb                 NaN        NaN        Domestics
# 632   1.0     0.0        flat            flat gap        NaN        Domestics
# 633   1.0     0.0  transition                pool        NaN        Domestics
# 634   0.0     0.0         gap            flat gap  into bank        Domestics
# 635   0.0     0.0  transition                pool        NaN        Domestics
# 636   0.0     0.0  transition      street quarter      ditch        OJ Wheels
# 637   0.0     0.0  transition     street halfpipe      ditch        OJ Wheels
# 638   0.0     0.0  transition                pool        NaN        OJ Wheels
# 639   0.0     0.0        rail           flat rail    to bank        OJ Wheels
# 640   1.0     0.0  transition                pool        NaN        OJ Wheels
# 641   1.0     0.0  transition                pool        NaN        OJ Wheels
# 642   0.0     0.0        wall        bank to wall        NaN        OJ Wheels
# 643   0.0     0.0  transition      street quarter      ditch        OJ Wheels
# 644   0.0     0.0  transition      street quarter      ditch        OJ Wheels
# 645   0.0     0.0  transition      street quarter        NaN        OJ Wheels
# 646   0.0     0.0       ledge        banked ledge        NaN        OJ Wheels
# 647   0.0     0.0        wall     quarter to wall        NaN        OJ Wheels
# 648   0.0     0.0        wall     quarter to wall        NaN        OJ Wheels
# 649   0.0     0.0  transition  quarter to quarter        NaN        OJ Wheels
# 650   1.0     0.0       ledge        banked ledge     gap to        OJ Wheels
# 651   1.0     0.0        flat                 NaN        NaN        OJ Wheels
# 652   0.0     0.0  transition        into quarter      ditch        OJ Wheels
# 653   0.0     0.0        wall         down stairs        NaN        OJ Wheels
#
#      year                                              notes  crust  \
# 0    1991                                                NaN    0.0
# 1    1991                                                NaN    0.0
# 2    1991                      entire part filmed in one day    0.0
# 3    1991                                                       0.0
# 4    1991                                                       0.0
# 5    1991                                                NaN    0.0
# 6    1991                                                NaN    0.0
# 7    1991                                                NaN    0.0
# 8    1991                                                NaN    0.0
# 9    1991                                                NaN    0.0
# 10   1991                                                NaN    0.0
# 11   1991                                                NaN    0.0
# 12   1991            all impossibles sort of 360 shove style    0.0
# 13   1991                                                NaN    0.0
# 14   1991                                                NaN    0.0
# 15   1991                                                NaN    0.0
# 16   1991                                                NaN    0.0
# 17   1991                                                NaN    0.0
# 18   1991                                                NaN    0.0
# 19   1991                                                NaN    0.0
# 20   1991                          plus rollaway flat tricks    0.0
# 21   1991                          mostly filmed in same day    0.0
# 22   1991                                                NaN    0.0
# 23   1991                           quarter in Granny's yard    0.0
# 24   1991                                                NaN    0.0
# 25   1991                                                NaN    0.0
# 26   1991                                                NaN    0.0
# 27   1991                                                NaN    0.0
# 28   1991                                                NaN    0.0
# 29   1991                                                NaN    0.0
# ..    ...                                                ...    ...
# 624  2013                                                NaN    1.0
# 625  2013                                                NaN    0.0
# 626  2013                                                NaN    1.0
# 627  2013                                                NaN    1.0
# 628  2013                     literally in bed of dump truck    1.0
# 629  2013                                                NaN    0.0
# 630  2013                                                NaN    1.0
# 631  2013                                                NaN    1.0
# 632  2013                                                NaN    1.0
# 633  2013                                                NaN    1.0
# 634  2013   clips in this reused later in Sober?, OJ Wheels.    0.0
# 635  2013  clips in this from previous vids Real Street, ...    1.0
# 636  2015  clips duplicated in Real Street not logged her...    1.0
# 637  2015                                                NaN    1.0
# 638  2015                                                NaN    1.0
# 639  2015                                                NaN    1.0
# 640  2015                                   several of these    0.0
# 641  2015                                                       0.0
# 642  2015                                                NaN    1.0
# 643  2015                                                NaN    1.0
# 644  2015                                                NaN    1.0
# 645  2015                                                NaN    1.0
# 646  2015                                                NaN    0.0
# 647  2015                                                NaN    1.0
# 648  2015                         alternate take of trick 14    1.0
# 649  2015                                                NaN    1.0
# 650  2015                                                NaN    1.0
# 651  2015                                                NaN    1.0
# 652  2015                                                NaN    1.0
# 653  2015                                               slam    0.0
#
#     Unnamed: 13 Unnamed: 14
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# 5           NaN         NaN
# 6           NaN         NaN
# 7           NaN         NaN
# 8           NaN         NaN
# 9           NaN
# 10          NaN
# 11          NaN         NaN
# 12          NaN         NaN
# 13          NaN
# 14          NaN         NaN
# 15          NaN         NaN
# 16          NaN         NaN
# 17          NaN         NaN
# 18          NaN         NaN
# 19          NaN         NaN
# 20          NaN         NaN
# 21          NaN         NaN
# 22          NaN         NaN
# 23          NaN         NaN
# 24          NaN         NaN
# 25          NaN         NaN
# 26          NaN         NaN
# 27          NaN         NaN
# 28          NaN         NaN
# 29          NaN         NaN
# ..          ...         ...
# 624         NaN         NaN
# 625         NaN         NaN
# 626         NaN         NaN
# 627         NaN         NaN
# 628         NaN         NaN
# 629         NaN         NaN
# 630         NaN         NaN
# 631         NaN         NaN
# 632         NaN         NaN
# 633         NaN         NaN
# 634         NaN         NaN
# 635         NaN         NaN
# 636         NaN         NaN
# 637         NaN         NaN
# 638         NaN         NaN
# 639         NaN         NaN
# 640         NaN         NaN
# 641         NaN         NaN
# 642         NaN         NaN
# 643         NaN         NaN
# 644         NaN         NaN
# 645         NaN         NaN
# 646         NaN         NaN
# 647         NaN         NaN
# 648         NaN         NaN
# 649         NaN         NaN
# 650         NaN         NaN
# 651         NaN         NaN
# 652         NaN         NaN
# 653         NaN         NaN
#
# [654 rows x 15 columns]

# %%
df.loc[df.line == 1].groupby('video').nunique()
# Out:
#                           clip_index  trick_index  trick  switch  line  \
# video
# 411 #8                             4           12     12       2     1
# Brutality                          8           15     13       1     1
# Decade of Destruction              7           11      9       1     1
# Dirts Win                          1            2      2       2     1
# Domestics                          2            5      5       1     1
# Eastern Exposure 2                 2            6      6       2     1
# Frontside Skate Shop               2            4      3       2     1
# Inhabitants                        8           16     15       2     1
# Last of the Mohicans               5           10     10       2     1
# Mosaic                             4           10     10       2     1
# OJ Wheels                          2            4      4       1     1
# Photosynthesis                     3            7      7       2     1
# Real Life                          4           15     11       2     1
# Real Street                        2            5      5       1     1
# Sober?                             2            4      4       1     1
# Stacked                            2            4      4       1     1
# The Brotherhood                    3            9      8       2     1
# The Other Ones                     6           12     12       2     1
# Thrasher Feats                     1            3      3       1     1
# Timecode                           5           16     10       2     1
# Worst Skater of the Year           3            8      7       2     1
#
#                           slowmo  obstacle  obstacle_detailed  location  \
# video
# 411 #8                         1         2                  1         2
# Brutality                      1         7                  7         2
# Decade of Destruction          1         4                  4         2
# Dirts Win                      1         2                  1         0
# Domestics                      1         4                  2         0
# Eastern Exposure 2             1         3                  0         2
# Frontside Skate Shop           1         3                  2         1
# Inhabitants                    1         7                  8         2
# Last of the Mohicans           1         4                  4         1
# Mosaic                         1         5                  5         0
# OJ Wheels                      1         3                  2         1
# Photosynthesis                 1         5                  2         0
# Real Life                      1         4                  4         3
# Real Street                    1         3                  3         0
# Sober?                         1         2                  2         1
# Stacked                        1         3                  2         0
# The Brotherhood                1         2                  0         0
# The Other Ones                 1         4                  5         2
# Thrasher Feats                 1         2                  1         1
# Timecode                       1         4                  4         3
# Worst Skater of the Year       1         3                  5         1
#
#                           video  year  notes  crust  Unnamed: 13  Unnamed: 14
# video
# 411 #8                        1     1      1      1            0            0
# Brutality                     1     1      0      2            0            0
# Decade of Destruction         1     1      1      2            0            0
# Dirts Win                     1     1      1      1            0            0
# Domestics                     1     1      0      2            0            0
# Eastern Exposure 2            1     1      1      1            0            0
# Frontside Skate Shop          1     1      0      2            0            0
# Inhabitants                   1     1      0      2            0            0
# Last of the Mohicans          1     1      0      2            0            0
# Mosaic                        1     1      0      2            0            0
# OJ Wheels                     1     1      2      2            0            0
# Photosynthesis                1     1      1      1            0            0
# Real Life                     1     1      1      1            0            0
# Real Street                   1     1      0      2            0            0
# Sober?                        1     1      0      1            0            0
# Stacked                       1     1      0      1            0            0
# The Brotherhood               1     1      3      1            0            0
# The Other Ones                1     1      0      2            0            0
# Thrasher Feats                1     1      0      1            0            0
# Timecode                      1     1      1      2            0            0
# Worst Skater of the Year      1     1      0      2            0            0

# %%
df.loc[df.video == "Eastern Exposure 3"]
# Out:
#      clip_index  trick_index                          trick  switch  line  \
# 143           1            1               bs 5-0 to bs 180     0.0   0.0
# 144           2            2             fs 50-50 to fs 180     0.0   0.0
# 145           3            3  ollie up to ollie to fs 50-50     0.0   0.0
# 146           4            4                          ollie     0.0   0.0
#
#      slowmo obstacle obstacle_detailed   location               video  year  \
# 143     1.0    ledge               NaN        NaN  Eastern Exposure 3  1996
# 144     1.0     rail         flat rail        NaN  Eastern Exposure 3  1996
# 145     1.0     rail         flat rail  Love Park  Eastern Exposure 3  1996
# 146     0.0      gap               NaN        NaN  Eastern Exposure 3  1996
#
#                     notes  crust Unnamed: 13 Unnamed: 14
# 143                   NaN    0.0         NaN         NaN
# 144                   NaN    0.0         NaN         NaN
# 145  infamous crack trick    0.0         NaN         NaN
# 146                   NaN    0.0         NaN         NaN
